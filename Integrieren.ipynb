# %%
Sekantenverfahren

# %%
import math
x = math.pi /4
a =0
b= math.pi
f = lambda x: math.sin(x)
n = 4

result = (
                 (f(a)+f(b))/2 +
                 f(x) +
                 f(2*x)+
                 f(3*x)
)
print(result)
# Out:
# 2.414213562373095

# %% [markdown]
# Simpson-Regel

# %%
import math
x1 = math.pi /4
x = lambda x: x * x1
a =0
b= math.pi
f = lambda x: math.sin(x)
n = 4
h= (b-a)/n


result = (
                 h/3 * (
                 f(x(0)) +
                 4 * (f(x(1)+f(x(3)))) +
                 2 * f(x(2)) +
                 f(x(n)k)
                        )
)
print(result)
# Out:
# 1.5675885459000711
